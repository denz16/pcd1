# %%
import cv2
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

# %%
# memanggil citra sebagai grayscale (argument 0)
img = cv2.imread('13.jpg',0)

# Lakukan Thresholding
# Binary Threshold
ret,th1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)

# Adaptive Threshold dengan Mean
th2 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_MEAN_C,\
            cv2.THRESH_BINARY,11,2)

# Adaptive Threshold dengan Gaussian
th3 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,\
            cv2.THRESH_BINARY,11,2)

# Menerapkan Gaussian filtering sebelum Otsu’s thresholding
blur = cv2.GaussianBlur(img,(5,5),0)

# Otsu
ret3,th3 = cv2.threshold(blur,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)

# Plotting
titles = ['Original Image', 'Global Thresholding (v = 127)',
            'Adaptive Mean Thresholding', 'Adaptive Gaussian Thresholding']
images = [img, th1, th2, th3]

# menampilkan hasil
for i in range(4):
    plt.subplot(2,2,i+1)
    plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
plt.imshow(th3,'gray')
plt.show()

# %%
# Adaptive Threshold dengan Mean
th2 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_MEAN_C,\
            cv2.THRESH_BINARY,11,2)

plt.imshow(th2,'gray')
plt.show()

# %%
# memanggil citra sebagai grayscale (argument 0)
img = cv2.imread('5.jpg',0)

# Lakukan Thresholding
# Binary Threshold
ret,th1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)

plt.imshow(th1,'gray')
plt.show()

# %%
# Menerapkan Gaussian filtering sebelum Otsu’s thresholding
blur = cv2.GaussianBlur(img,(5,5),0)

# Otsu
ret3,th3 = cv2.threshold(blur,1.142857,0.63492,cv2.THRESH_BINARY+cv2.THRESH_OTSU)

# Plotting
plt.imshow(th3,'gray')
plt.show()

# %%
# memanggil citra sebagai grayscale (argument 0)
img = cv2.imread('14.jpg',0)

# Menerapkan Gaussian filtering sebelum Otsu’s thresholding
blur = cv2.GaussianBlur(img,(5,5),0)

# Otsu
ret3,th3 = cv2.threshold(blur,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)

plt.imshow(th3,'gray')
plt.show()

# %%
# memanggil citra sebagai grayscale (argument 0)
img = cv2.imread('22.jpg',0)

# Menerapkan Gaussian filtering sebelum Otsu’s thresholding
blur = cv2.GaussianBlur(img,(5,5),0)

# Otsu
ret3,th3 = cv2.threshold(blur,1.142857,0.63492,cv2.THRESH_BINARY+cv2.THRESH_OTSU)

# Plotting
plt.imshow(th3,'gray')
plt.show()

# %%
# memanggil citra sebagai grayscale (argument 0)
img = cv2.imread('25.jpg',0)

# Menerapkan Gaussian filtering sebelum Otsu’s thresholding
blur = cv2.GaussianBlur(img,(5,5),0)

# Otsu
ret3,th3 = cv2.threshold(blur,1.25,0.52777,cv2.THRESH_BINARY+cv2.THRESH_OTSU)

# Plotting
plt.imshow(th3,'gray')
plt.show()

# %%
# memanggil citra sebagai grayscale (argument 0)
img = cv2.imread('37.jpg',0)

# Menerapkan Gaussian filtering sebelum Otsu’s thresholding
blur = cv2.GaussianBlur(img,(5,5),0)

# Otsu
ret3,th3 = cv2.threshold(blur,0.5,1.277777,cv2.THRESH_BINARY+cv2.THRESH_OTSU)

# Plotting
plt.imshow(th3,'gray')
plt.show()

# %%
# memanggil citra sebagai grayscale (argument 0)
img = cv2.imread('39.jpg',0)

# Menerapkan Gaussian filtering sebelum Otsu’s thresholding
blur = cv2.GaussianBlur(img,(5,5),0)

# Otsu
ret3,th3 = cv2.threshold(blur,0,1.77777,cv2.THRESH_BINARY+cv2.THRESH_OTSU)

# Plotting
plt.imshow(th3,'gray')
plt.show()

# %%
# memanggil citra sebagai grayscale (argument 0)
img = cv2.imread('0.jpg',0)

# Menerapkan Gaussian filtering sebelum Otsu’s thresholding
blur = cv2.GaussianBlur(img,(5,5),0)

ret,th1 = cv2.threshold(img,175,100,cv2.THRESH_BINARY)

plt.imshow(th1,'gray')
plt.show()

# %%
# memanggil citra sebagai grayscale (argument 0)
img = cv2.imread('9.jpg',0)

# Menerapkan Gaussian filtering sebelum Otsu’s thresholding
blur = cv2.GaussianBlur(img,(5,5),0)

ret,th1 = cv2.threshold(img,225,120,cv2.THRESH_BINARY)

plt.imshow(th1,'gray')
plt.show()

# %%
# memanggil citra sebagai grayscale (argument 0)
img = cv2.imread('17.jpg',0)

# Menerapkan Gaussian filtering sebelum Otsu’s thresholding
blur = cv2.GaussianBlur(img,(5,5),0)

ret,th1 = cv2.threshold(img,115,240,cv2.THRESH_BINARY)

plt.imshow(th1,'gray')
plt.show()
